# %%
cart = []

cart.append("Apple")
cart.append("Milk")
cart.append("Bread")
cart.append("Eggs")

print("Cart after adding items:", cart)

cart.remove("Milk")

print("Cart after removing an item:", cart)

print("Total number of items in cart:", len(cart))
# Out:
# Cart after adding items: ['Apple', 'Milk', 'Bread', 'Eggs']
# Cart after removing an item: ['Apple', 'Bread', 'Eggs']
# Total number of items in cart: 3
